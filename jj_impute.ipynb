# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# %matplotlib inline

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

#imputer.py must be in directory
#please look at doc_strings for HousingImpute class
import jj_imputer

# %%
housing = jj_imputer.HousingImpute('train.csv')
# Out:
# LotFrontage 259
# Alley 1369
# MasVnrType 8
# MasVnrArea 8
# BsmtQual 37
# BsmtCond 37
# BsmtExposure 38
# BsmtFinType1 37
# BsmtFinType2 38
# Electrical 1
# FireplaceQu 690
# GarageType 81
# GarageYrBlt 81
# GarageFinish 81
# GarageQual 81
# GarageCond 81
# PoolQC 1453
# Fence 1179
# MiscFeature 1406

# %%
housing.run_imputers()
# Out:
# MasVnrArea imputer embedded in another imputer
# BsmtCond imputer embedded in another imputer
# BsmtExposure imputer embedded in another imputer
# BsmtFinType1 imputer embedded in another imputer
# BsmtFinType2 imputer embedded in another imputer
# GarageYrBlt imputer embedded in another imputer
# GarageFinish imputer embedded in another imputer
# GarageQual imputer embedded in another imputer
# GarageCond imputer embedded in another imputer

# %%
housing.left_to_impute()
# Out:
# BsmtExposure 1
# --------------------
# Id
# 949    NaN
# Name: BsmtExposure, dtype: object
# --------------------
# BsmtFinType2 1
# --------------------
# Id
# 333    NaN
# Name: BsmtFinType2, dtype: object
# --------------------

# %% [markdown]
# indx 949 has NaN BsmtExposure but a basement condition/qual with 0 finished area. Will impute as 'No'

# %%
housing.df.loc[949, 'BsmtExposure'] = 'No'

# %% [markdown]
# index 333 is imputed as Rec via median value since the missing competely at random BsmFinType2 value .

# %%
housing.df.loc[333, 'BsmtFinType2'] = 'Rec'

# %%
housing.df.sample(20)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street     Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea   PoolQC     Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  SalePrice
# Id
# 1423         120       RM    37.000000     4435   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl      CollgCr       Norm       Norm   TwnhsE     1Story            6            5       2003          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace       170.0        Gd        TA      PConc       Gd       TA           Av          GLQ         686          Unf           0        162          848    GasA        Ex          Y      SBrkr       848         0             0        848             1             0         1         0             1             1          Gd             3        Typ           0       No_FP     Attchd       2003.0          Fin           2         420         TA         TA          Y         140            0              0          0            0         0  No_Pool  No_Fence       No_MF        0       3    2008       WD        Normal     136500
# 1190          60       RL    60.000000     7500   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl      Gilbert       Norm       Norm     1Fam     2Story            7            5       1999          1999     Gable  CompShg     VinylSd     VinylSd       None         0.0        TA        TA      PConc       TA       TA           No          Unf           0          Unf           0        994          994    GasA        Gd          Y      SBrkr      1028       776             0       1804             0             0         2         1             3             1          Gd             7        Typ           1          TA     Attchd       1999.0          Fin           2         442         TA         TA          Y         140           60              0          0            0         0  No_Pool  No_Fence       No_MF        0       6    2010       WD        Normal     189000
# 142           20       RL    78.000000    11645   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam     1Story            7            5       2005          2005     Gable  CompShg     VinylSd     VinylSd       None         0.0        Gd        TA      PConc       Gd       TA           Av          GLQ        1300          Unf           0        434         1734    GasA        Ex          Y      SBrkr      1734         0             0       1734             1             0         2         0             3             1          Gd             7        Typ           0       No_FP     Attchd       2005.0          Fin           2         660         TA         TA          Y         160           24              0          0            0         0  No_Pool  No_Fence       No_MF        0       1    2006       WD        Normal     260000
# 465           20       RL    60.000000     8430   Pave  No_Alley      Reg         HLS    AllPub    Inside       Mod      CollgCr       Norm       Norm     1Fam     1Story            5            5       1978          1978     Gable  CompShg     HdBoard     HdBoard    BrkFace       136.0        TA        TA     CBlock       Gd       TA           No          Rec         616          Unf           0        424         1040    GasA        TA          Y      SBrkr      1040         0             0       1040             0             0         2         0             3             1          TA             5        Typ           0       No_FP       No_G       1978.0         No_G           0           0       No_G       No_G          Y           0            0              0          0            0         0  No_Pool  No_Fence       No_MF        0       8    2009       WD        Normal     124000
# 652           70       RL    60.000000     9084   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl      Edwards     Artery       Norm     1Fam     2Story            4            5       1940          1950     Gable  CompShg     MetalSd     MetalSd       None         0.0        TA        TA     CBlock       TA       TA           Mn          Unf           0          Unf           0        755          755    GasA        TA          Y      SBrkr       755       755             0       1510             1             0         1         0             4             1          TA             7        Typ           1          Gd     Detchd       1940.0          Unf           1         296         Fa         Po          P         120            0              0          0            0         0  No_Pool     MnPrv       No_MF        0      10    2009       WD        Normal     108000
# 1118          20       RL    57.000000     9764   Pave  No_Alley      IR1         Lvl    AllPub       FR2       Gtl       Sawyer      Feedr       Norm     1Fam     1Story            5            7       1967          2003     Gable  CompShg     VinylSd     VinylSd       None         0.0        TA        TA     CBlock       TA       TA           No          BLQ         702          Unf           0        192          894    GasA        Ex          Y      SBrkr       894         0             0        894             1             0         1         0             3             1          Gd             5        Typ           0       No_FP     Attchd       1967.0          RFn           2         450         TA         TA          Y           0            0              0          0            0         0  No_Pool  No_Fence       No_MF        0       5    2008       WD        Normal     130000
# 860           60       RL    72.395856    11029   Pave  No_Alley      IR1         Lvl    AllPub    Corner       Gtl       NWAmes       PosA       Norm     1Fam     2Story            6            7       1968          1984     Gable  CompShg     HdBoard     HdBoard    BrkFace       220.0        TA        TA     CBlock       TA       TA           Mn          BLQ         619          Unf           0        435         1054    GasA        TA          Y      SBrkr      1512      1142             0       2654             1             0         2         1             4             1          Gd             9        Typ           1          Gd     Attchd       1968.0          Unf           2         619         TA         TA          Y           0           65              0          0          222         0  No_Pool  No_Fence       No_MF        0       8    2006       WD        Normal     250000
# 101           20       RL    71.478303    10603   Pave  No_Alley      IR1         Lvl    AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam     1Story            6            7       1977          2001     Gable  CompShg     Plywood     Plywood    BrkFace        28.0        TA        TA      PConc       TA       TA           Mn          ALQ        1200          Unf           0        410         1610    GasA        Gd          Y      SBrkr      1610         0             0       1610             1             0         2         0             3             1          Gd             6        Typ           2          TA     Attchd       1977.0          RFn           2         480         TA         TA          Y         168           68              0          0            0         0  No_Pool  No_Fence       No_MF        0       2    2010       WD        Normal     205000
# 388           80       RL    72.000000     7200   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl      Edwards       Norm       Norm     1Fam       SLvl            6            6       1976          1976       Hip  CompShg     MetalSd     MetalSd    BrkFace       255.0        TA        TA     CBlock       TA       TA           Av          ALQ         631          Unf           0        410         1041    GasA        Ex          Y      SBrkr      1125         0             0       1125             1             0         1         0             3             1          TA             6        Typ           1          Fa     Detchd       1977.0          Unf           1         352         TA         TA          Y         296            0              0          0            0         0  No_Pool      GdWo       No_MF        0      10    2009       WD       Abnorml     125000
# 1037          20       RL    89.000000    12898   Pave  No_Alley      IR1         HLS    AllPub    Inside       Gtl       Timber       Norm       Norm     1Fam     1Story            9            5       2007          2008       Hip  CompShg     VinylSd     VinylSd      Stone        70.0        Gd        TA      PConc       Ex       TA           Gd          GLQ        1022          Unf           0        598         1620    GasA        Ex          Y      SBrkr      1620         0             0       1620             1             0         2         0             2             1          Ex             6        Typ           1          Ex     Attchd       2008.0          Fin           3         912         TA         TA          Y         228            0              0          0            0         0  No_Pool  No_Fence       No_MF        0       9    2009       WD        Normal     315500
# 1228          20       RL    72.000000     8872   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl        NAmes       Norm       Norm     1Fam     1Story            5            8       1965          2008     Gable  CompShg     VinylSd     VinylSd    BrkFace       300.0        TA        TA     CBlock       TA       TA           No          ALQ         595          Unf           0        317          912    GasA        Ex          Y      SBrkr       912         0             0        912             1             0         1         0             2             1          Gd             5        Typ           0       No_FP     Detchd       1992.0          Unf           2         576         TA         TA          Y           0          240              0          0            0         0  No_Pool  No_Fence       No_MF        0      12    2008       WD        Normal     147000
# 1381          30       RL    45.000000     8212   Pave      Grvl      Reg         Lvl    AllPub    Inside       Gtl      Edwards       Norm       Norm     1Fam     1Story            3            3       1914          1950     Gable  CompShg      Stucco      Stucco       None         0.0        TA        Fa     BrkTil       TA       Fa           No          Rec         203          Unf           0        661          864    GasA        TA          N      FuseF       864         0             0        864             1             0         1         0             2             1          TA             5        Typ           0       No_FP     Detchd       1938.0          Unf           1         200         TA         Fa          Y           0            0             96          0            0         0  No_Pool  No_Fence       No_MF        0       6    2010       WD        Normal      58500
# 1039         160       RM    21.000000     1533   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl      MeadowV       Norm       Norm    Twnhs     2Story            4            6       1970          2008     Gable  CompShg     CemntBd     CmentBd       None         0.0        TA        TA     CBlock       TA       TA           No          Unf           0          Unf           0        546          546    GasA        TA          Y      SBrkr       798       546             0       1344             0             0         1         1             3             1          TA             6        Typ           1          TA       No_G       1970.0         No_G           0           0       No_G       No_G          Y           0            0              0          0            0         0  No_Pool  No_Fence       No_MF        0       5    2009       WD        Normal      97000
# 426           60       RM    60.000000     3378   Pave      Grvl      Reg         HLS    AllPub    Inside       Gtl      OldTown       Norm       Norm     1Fam     2Story            7            8       1946          1992     Gable  CompShg     HdBoard     HdBoard       None         0.0        TA        Gd     CBlock       TA       TA           No          Unf           0          Unf           0        651          651    GasA        Gd          Y      SBrkr       707       682             0       1389             0             0         1         1             3             1          TA             6        Typ           2          Gd     Detchd       1947.0          Unf           1         240         TA         TA          P           0            0            126          0            0         0  No_Pool  No_Fence       No_MF        0       9    2009       WD        Normal     135000
# 789           20       RM    50.000000     6000   Pave  No_Alley      Reg         Lvl    AllPub    Corner       Gtl      OldTown       Norm       Norm     1Fam     1Story            4            7       1954          2000     Gable  CompShg     MetalSd     MetalSd       None         0.0        TA        TA     CBlock       TA       TA           No          Unf           0          Unf           0        901          901    GasA        Ex          Y      SBrkr       901         0             0        901             0             0         1         0             2             1          TA             4        Typ           0       No_FP     Detchd       1954.0          Unf           1         281         Fa         TA          Y           0            0              0          0            0         0  No_Pool  No_Fence       No_MF        0       8    2008       WD        Normal     107900
# 619           20       RL    90.000000    11694   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl      NridgHt       Norm       Norm     1Fam     1Story            9            5       2007          2007       Hip  CompShg     CemntBd     CmentBd    BrkFace       452.0        Ex        TA      PConc       Ex       TA           Av          GLQ          48          Unf           0       1774         1822    GasA        Ex          Y      SBrkr      1828         0             0       1828             0             0         2         0             3             1          Gd             9        Typ           1          Gd     Attchd       2007.0          Unf           3         774         TA         TA          Y           0          108              0          0          260         0  No_Pool  No_Fence       No_MF        0       7    2007      New       Partial     314813
# 64            70       RM    50.000000    10300   Pave  No_Alley      IR1         Bnk    AllPub    Inside       Gtl      OldTown       RRAn      Feedr     1Fam     2Story            7            6       1921          1950     Gable  CompShg      Stucco      Stucco       None         0.0        TA        TA     BrkTil       TA       TA           No          Unf           0          Unf           0        576          576    GasA        Gd          Y      SBrkr       902       808             0       1710             0             0         2         0             3             1          TA             9        Typ           0       No_FP     Detchd       1990.0          Unf           2         480         TA         TA          Y          12           11             64          0            0         0  No_Pool     GdPrv       No_MF        0       4    2010       WD        Normal     140000
# 28            20       RL    98.000000    11478   Pave  No_Alley      Reg         Lvl    AllPub    Inside       Gtl      NridgHt       Norm       Norm     1Fam     1Story            8            5       2007          2008     Gable  CompShg     VinylSd     VinylSd      Stone       200.0        Gd        TA      PConc       Ex       TA           No          GLQ        1218          Unf           0        486         1704    GasA        Ex          Y      SBrkr      1704         0             0       1704             1             0         2         0             3             1          Gd             7        Typ           1          Gd     Attchd       2008.0          RFn           3         772         TA         TA          Y           0           50              0          0            0         0  No_Pool  No_Fence       No_MF        0       5    2010       WD        Normal     306000
# 1307         120       RL    48.000000     6955   Pave  No_Alley      IR1         Lvl    AllPub    Inside       Gtl      NridgHt       Norm       Norm   TwnhsE     1Story            7            5       2005          2006     Gable  CompShg     VinylSd     VinylSd      Stone        94.0        Gd        TA      PConc       Gd       TA           No          Unf           0          Unf           0       1368         1368    GasA        Ex          Y      SBrkr      1368         0             0       1368             0             0         2         0             2             1          Gd             6        Typ           1          Gd     Attchd       2005.0          RFn           2         474         TA         TA          Y         132           35              0          0            0         0  No_Pool  No_Fence       No_MF        0       9    2006      New       Partial     202500
# 1273          20       RL    77.774094    13526   Pave  No_Alley      IR1         Lvl    AllPub   CulDSac       Gtl       Sawyer       Norm       Norm     1Fam     1Story            5            6       1965          1965       Hip  CompShg     HdBoard     Plywood    BrkFace       114.0        TA        TA     CBlock       TA       TA           No          BLQ         560          LwQ         375          0          935    GasA        TA          Y      SBrkr       935         0             0        935             1             0         1         0             3             1          TA             5        Typ           0       No_FP     Attchd       1965.0          Unf           1         288         TA         TA          Y         180            0              0          0            0         0  No_Pool     MnPrv       No_MF        0      11    2006       WD        Normal     137000

# %%
#final check for missing values
housing.left_to_impute()

# %% [markdown]
# The following three changes were made after further EDA and placed here to merge copies of train_imputed.csv

# %%
housing.df.drop('Utilities', axis=1, inplace=True)
#drop utilities since 1459 out of 1600 share same value
housing.df.drop('TotalBsmtSF', axis=1, inplace=True)
#drop TotalBsmtSF for multicollinearity since it is the sum of the 3 other BsmtSF columns

housing.df.loc[:,'Exterior2nd'].replace('CmentBd','CemntBd', inplace=True)
#correcting for spelling errors to make the types of values in Exterior1st and Exterior2nd the same

# %%
housing.save_df('train_imputed')
