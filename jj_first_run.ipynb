# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 1000)

df = pd.read_csv('train.csv', index_col=0)

# %%
df.shape
df.head(10)
# Out:
# (1460, 80)
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 7           20       RL         75.0    10084   Pave   NaN      Reg
# 8           60       RL          NaN    10382   Pave   NaN      IR1
# 9           50       RM         51.0     6120   Pave   NaN      Reg
# 10         190       RL         50.0     7420   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# ...

# %% [markdown]
# 1460 houses with 79 features each and 1 response variable

# %%
df.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315  ...
# std      30.202904     20.645407   181.066207   456.098091   161.319273  ...
# ...

# %% [markdown]
# lets look at the different dtypes for all the columns in this df. due to there being 79 columns, it was hard to view in aggregate. we will look at each potential datatype.

# %%
df.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %%
df.dtypes[df.dtypes=='object'] #probably will 1 hot encode these or use label encoder if there is heirarchel ranks
# Out:
# MSZoning         object
# Street           object
# Alley            object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# BsmtFinType2     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# FireplaceQu      object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# GarageCond       object
# PavedDrive       object
# ...

# %%
df.dtypes[df.dtypes=='float64']
# Out:
# LotFrontage    float64
# MasVnrArea     float64
# GarageYrBlt    float64
# dtype: object

# %%
df.dtypes[df.dtypes=='int64'] #do we cast year and month sold as category labels?
#def need to recast mssubclass
# Out:
# MSSubClass       int64
# LotArea          int64
# OverallQual      int64
# OverallCond      int64
# YearBuilt        int64
# YearRemodAdd     int64
# BsmtFinSF1       int64
# BsmtFinSF2       int64
# BsmtUnfSF        int64
# TotalBsmtSF      int64
# 1stFlrSF         int64
# 2ndFlrSF         int64
# LowQualFinSF     int64
# GrLivArea        int64
# BsmtFullBath     int64
# BsmtHalfBath     int64
# FullBath         int64
# HalfBath         int64
# BedroomAbvGr     int64
# KitchenAbvGr     int64
# TotRmsAbvGrd     int64
# Fireplaces       int64
# GarageCars       int64
# GarageArea       int64
# WoodDeckSF       int64
# OpenPorchSF      int64
# EnclosedPorch    int64
# 3SsnPorch        int64
# ScreenPorch      int64
# PoolArea         int64
# MiscVal          int64
# MoSold           int64
# YrSold           int64
# SalePrice        int64
# dtype: object

# %%
null_counter = df.isnull().sum()
for i in range(len(null_counter)):
    if null_counter[i] > 0:
               print(df.columns[i] , null_counter[i])
# Out:
# LotFrontage 259
# Alley 1369
# MasVnrType 8
# MasVnrArea 8
# BsmtQual 37
# BsmtCond 37
# BsmtExposure 38
# BsmtFinType1 37
# BsmtFinType2 38
# Electrical 1
# FireplaceQu 690
# GarageType 81
# GarageYrBlt 81
# GarageFinish 81
# GarageQual 81
# GarageCond 81
# PoolQC 1453
# Fence 1179
# MiscFeature 1406

# %% [markdown]
# 1. we will look at the NAN values and impute
# 2. we will look at int columns and see which ones need to be converted to categorical data
# 3. we will look at obj columns and perform get_dummies()/one_hot_encoding

# %%
df_missing_LotFrontage = df.loc[df.LotFrontage.isnull(),:]
df_missing_LotFrontage.SalePrice.describe()
df.SalePrice.describe()
# Out:
# count       259.000000
# mean     181620.073359
# std       57841.775706
# min       61000.000000
# 25%      143375.000000
# 50%      172400.000000
# 75%      215000.000000
# max      466500.000000
# Name: SalePrice, dtype: float64
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
for i in df_missing_LotFrontage.columns:
    df_missing_LotFrontage[i].value_counts()
# Out:
# 20     99
# 60     69
# 120    20
# 80     20
# 50     16
# 160     8
# 85      6
# 30      6
# 90      5
# 70      5
# 190     3
# 75      1
# 40      1
# Name: MSSubClass, dtype: int64
# RL    229
# RM     19
# FV      8
# RH      3
# Name: MSZoning, dtype: int64
# Series([], Name: LotFrontage, dtype: int64)
# 4426      3
# 11250     3
# 2117      3
# 7750      3
# 12155     2
# 3196      2
# 8544      2
# 9790      2
# 8125      2
# 7500      2
# 4435      2
# 9819      2
# 4438      2
# 4928      2
# 11500     2
# 9375      2
# 11616     2
# 7758      2
# 12342     2
# 11000     2
# 7861      1
# 5814      1
# 11200     1
# 8880      1
# 7340      1
# 8854      1
# 7917      1
# 7851      1
# 12968     1
# 9101      1
# 6820      1
# 11425     1
# 4500      1
# 29959     1
# 8780      1
# 10395     1
# 5271      1
# 15870     1
# 13517     1
# 13500     1
# 9947      1
# 13006     1
# 17140     1
# 6897      1
# 7920      1
# 2651      1
# 9453      1
# 19690     1
# 13031     1
# ...

# %%
for i in df.columns:
    df[i].value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
# 60.0     143
# 70.0      70
# 80.0      69
# 50.0      57
# 75.0      53
# 65.0      44
# 85.0      40
# 78.0      25
# 21.0      23
# 90.0      23
# 68.0      19
# 24.0      19
# 64.0      19
# 73.0      18
# 72.0      17
# 79.0      17
# 63.0      17
# 55.0      17
# 100.0     16
# 51.0      15
# 66.0      15
# 74.0      15
# 52.0      14
# 59.0      13
# 71.0      12
# 82.0      12
# 40.0      12
# 43.0      12
# 67.0      12
# 57.0      12
# 69.0      11
# 76.0      11
# 86.0      10
# 53.0      10
# 34.0      10
# 92.0      10
# 88.0      10
# 62.0       9
# 44.0       9
# 84.0       9
# 77.0       9
# 35.0       9
# 93.0       8
# ...

# %%
df.LotFrontage.describe()
# Out:
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %% [markdown]
# column LotFrontage seems to be missing completely at random and can be imputed via random sampling.

# %%
import sklearn

# %%
help(sklearn.impute)
# Out:
# Help on module sklearn.impute in sklearn:
#
# NAME
#     sklearn.impute - Transformers for missing value imputation
#
# CLASSES
#     sklearn.base.BaseEstimator(builtins.object)
#         MissingIndicator(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin)
#         SimpleImputer(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin)
#     sklearn.base.TransformerMixin(builtins.object)
#         MissingIndicator(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin)
#         SimpleImputer(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin)
#
#     class MissingIndicator(sklearn.base.BaseEstimator, sklearn.base.TransformerMixin)
#      |  MissingIndicator(missing_values=nan, features='missing-only', sparse='auto', error_on_new=True)
#      |
#      |  Binary indicators for missing values.
#      |
#      |  Note that this component typically should not not be used in a vanilla
#      |  :class:`Pipeline` consisting of transformers and a classifier, but rather
# ...
